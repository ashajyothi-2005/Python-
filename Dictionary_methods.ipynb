# %% [markdown]
# <a href="https://colab.research.google.com/github/ashajyothi-2005/Python-/blob/main/Dictionary_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= { "name":"john","age":20}
print(x)
type(x)
# Out:
# {'name': 'john', 'age': 20}
# dict

# %%
x={"name":"john","age":26}
print (x.keys())
# Out:
# dict_keys(['name', 'age'])

# %%
x={"name":"laxmi","age":34}
print(x.values())
# Out:
# dict_values(['laxmi', 34])

# %%
x={"name":"gopi","age":36}
print(x. items())
# Out:
# dict_items([('name', 'gopi'), ('age', 36)])

# %%
x={"name":"john","age":45}
print(x.get("name"))
# Out:
# john
