# %% [markdown]
# <a href="https://colab.research.google.com/github/ashajyothi-2005/Python-/blob/main/Data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x="Hello"
print(x)
type(x)
# Out:
# Hello
# str

# %%
x=(1,2,3,4,5,6,7,8,9,"apple")
print(min(x))
print(max(x))
print(type(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-6-2030586992.py in <cell line: 0>()
#       1 x=(1,2,3,4,5,6,7,8,9,"apple")
# ----> 2 print(min(x))
#       3 print(max(x))
#       4 print(type(x))
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
x=20
print(x)
type(x)
# Out:
# 20
# int

# %%
x=0.5
print(x)
type(x)
# Out:
# 0.5
# float

# %%
x=["apple","banana"]
print(x)
type(x)
# Out:
# ['apple', 'banana']
# list

# %%
x=("apple","banana")
print(x)
type(x)
# Out:
# ('apple', 'banana')
# tuple

# %%
x={"john","banana"}
print(x)
type(x)
