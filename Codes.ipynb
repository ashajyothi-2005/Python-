# %% [markdown]
# <a href="https://colab.research.google.com/github/ashajyothi-2005/Python-/blob/main/Codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input())
for num in range (2,n):
    for i in range (2,num):
         if num%i==0:
              break
    else:
        print(num,end=" ")
# Out:
# 10
# 2 3 5 7

# %%
n=int(input())
fact=1
for i in range (1,n+1):
     fact*=i
print(fact)
# Out:
# 5
# 120

# %%
a=int(input())
if(a%4==0 and a%100!=0) or a%400==0:
    print("leap year")
else:
    print("not leap year")
# Out:
# 2024
# leap year

# %%
n=int(input())
a,b=0,1
for i in range (n):
    print (a,end=" ")
    a,b=b,a+b
# Out:
# 7
# 0 1 1 2 3 5 8

# %%
n=int(input())
count=0
while n>0:
    n=n//10
    count+=1
print(count)
# Out:
# 2345
# 4

# %%
Hiin=int(input())
count=0
for i in str(n):
    count+=1
print (count)
# Out:
# 2354
# 4

# %%
n=int(input())
s=str(n)
if s==s[::-1]:
    print("palindrome")
else:
    print("not a palindrome")
# Out:
# 13231
# palindrome
