# %% [markdown]
# <a href="https://colab.research.google.com/github/ashajyothi-2005/Python-/blob/main/Tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=("apple","banana","mango")
print(x)
type(x)
# Out:
# ('apple', 'banana', 'mango')
# tuple

# %%
xtuple=(1,2,3)
print(xtuple.index(1))
# Out:
# 0

# %%
xtuple=(1,2,3,4,2,5)
print(xtuple.count(2))
# Out:
# 2
