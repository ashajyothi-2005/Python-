# %% [markdown]
# <a href="https://colab.research.google.com/github/ashajyothi-2005/Python-/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data1 = {'Id':[1,2,3],'Name':['rani','teju','asha'],'Age':[30,35,25]}
data2 = {'Id':[4,5,6],'Name':['raju','sanju','bunny'],'Age':[40,45,50]}
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
print(df1)
print(df2)
# Out:
#    Id  Name  Age
# 0   1  rani   30
# 1   2  teju   35
# 2   3  asha   25
#    Id   Name  Age
# 0   4   raju   40
# 1   5  sanju   45
# 2   6  bunny   50
