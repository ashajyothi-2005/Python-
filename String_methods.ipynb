# %% [markdown]
# <a href="https://colab.research.google.com/github/ashajyothi-2005/Python-/blob/main/String_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("""asha""")
# Out:
# asha

# %%
a='''asha'''
print(a)
# Out:
# asha

# %%
a="python is a programming 'language' "
print(a)
# Out:
# python is a programming 'language'

# %%
a='python is a programming "language" '
print(a)
# Out:
# python is a programming "language"

# %%
##classification methods
a= "Company 12"

x = a.isalnum()

print(x)
# Out:
# False

# %%
a= "50800"

x = a.isdigit()

print(x)
# Out:
# True

# %%
a= "asha"

x = a.isalpha()

print(x)
# Out:
# True

# %%
a= "asha"

x = a.islower()

print(x)
# Out:
# True

# %%
a= "Asha"

x = a.isupper()

print(x)
# Out:
# False

# %%
a="hello, and welcome to my world."
x=a.capitalize()
print(x)
# Out:
# Hello, and welcome to my world.

# %%
a="heLlo, and welcome To my world."
x=a.casefold()
print(x)
# Out:
# hello, and welcome to my world.

# %%
a="hello, and welcome to my world."
x=a.title()
print(x)
# Out:
# Hello, And Welcome To My World.

# %%
a="hello, and welcome to my world."
x=a.swapcase()
print(x)
# Out:
# HELLO, AND WELCOME TO MY WORLD.

# %%
a="HeLlo, and welcome To my world."
x=a.lower()
print(x)
# Out:
# hello, and welcome to my world.

# %%
a="HeLlo, and welcome To my world."
x=a.upper()
print(x)
# Out:
# HELLO, AND WELCOME TO MY WORLD.

# %%
a="HeLlo, and welcome To my world."
x=a.index("To")
print(x)
# Out:
# 19

# %%
a="HeLlo, and welcome To my world."
x=a.rindex("To")
print(x)
# Out:
# 19

# %%
a="HeLlo, and welcome To my world."
x=a.find("my")
print(x)
# Out:
# 22

# %%
a="HeLlo, and welcome To my world."
x=a.rfind("my")
print(x)
# Out:
# 22

# %%
a = "HeLlo, and welcome To my world."
try:
    x = a.index("a", 12, 17)
    print(x)
except ValueError:
    print("'a' not found in the specified range")
# Out:
# 'a' not found in the specified range

# %%
a = "HeLlo, and welcome To my world."
try:
    x = a.find("a", 12, 17)
    print(x)
except ValueError:
    print("'a' not found in the specified range")
# Out:
# -1

# %%
a="HeLlo, and welcome To my world."
x=a.startswith("my")
print(x)
# Out:
# False

# %%
a="HeLlo, and welcome To my world."
x=a.endswith("my")
print(x)
# Out:
# False

# %%
a="  Hello   "
x=a.strip()
print(x)
# Out:
# Hello

# %%
a="  Hello   "
x=a.rstrip()
print(x)
# Out:
#   Hello

# %%
a="  Hello   "
x=a.lstrip()
print(x)
# Out:
# Hello
